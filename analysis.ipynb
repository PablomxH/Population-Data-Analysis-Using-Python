# %% [markdown]
# # Welcome to Population Analysis Notebook

# %% [markdown]
# ### Let's Import the modules

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
print('Modules are imported')
population = pd.read_csv('./population.csv', sep=',',header=0)
population
# Out:
# Modules are imported
#      Rank CCA3  Country/Territory           Capital Continent  \
# 0      36  AFG        Afghanistan             Kabul      Asia
# 1     138  ALB            Albania            Tirana    Europe
# 2      34  DZA            Algeria           Algiers    Africa
# 3     213  ASM     American Samoa         Pago Pago   Oceania
# 4     203  AND            Andorra  Andorra la Vella    Europe
# ..    ...  ...                ...               ...       ...
# 229   226  WLF  Wallis and Futuna          Mata-Utu   Oceania
# 230   172  ESH     Western Sahara          El Aaiún    Africa
# 231    46  YEM              Yemen             Sanaa      Asia
# 232    63  ZMB             Zambia            Lusaka    Africa
# 233    74  ZWE           Zimbabwe            Harare    Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0           41128771         38972230         33753499         28189672
# ...

# %% [markdown]
# # Overall data

# %% [markdown]
# ### Statistical data

# %%
population.describe()
# Out:
#              Rank  2022 Population  2020 Population  2015 Population  \
# count  234.000000     2.340000e+02     2.340000e+02     2.340000e+02
# mean   117.500000     3.407441e+07     3.350107e+07     3.172996e+07
# std     67.694165     1.367664e+08     1.355899e+08     1.304050e+08
# min      1.000000     5.100000e+02     5.200000e+02     5.640000e+02
# 25%     59.250000     4.197385e+05     4.152845e+05     4.046760e+05
# 50%    117.500000     5.559944e+06     5.493074e+06     5.307400e+06
# 75%    175.750000     2.247650e+07     2.144798e+07     1.973085e+07
# max    234.000000     1.425887e+09     1.424930e+09     1.393715e+09
#
#        2010 Population  2000 Population  1990 Population  1980 Population  \
# count     2.340000e+02     2.340000e+02     2.340000e+02     2.340000e+02
# mean      2.984524e+07     2.626947e+07     2.271022e+07     1.898462e+07
# std       1.242185e+08     1.116982e+08     9.783217e+07     8.178519e+07
# ...

# %% [markdown]
# ### Memory usage

# %%
population.memory_usage(deep=True)
# Out:
# Index                            128
# Rank                            1872
# CCA3                           14040
# Country/Territory              15456
# Capital                        15505
# Continent                      15043
# 2022 Population                 1872
# 2020 Population                 1872
# 2015 Population                 1872
# 2010 Population                 1872
# 2000 Population                 1872
# 1990 Population                 1872
# 1980 Population                 1872
# 1970 Population                 1872
# Area (km²)                      1872
# Density (per km²)               1872
# Growth Rate                     1872
# World Population Percentage     1872
# dtype: int64

# %% [markdown]
# ### Delete duplicates

# %%
population.drop_duplicates(keep='last')
# Out:
#      Rank CCA3  Country/Territory           Capital Continent  \
# 0      36  AFG        Afghanistan             Kabul      Asia
# 1     138  ALB            Albania            Tirana    Europe
# 2      34  DZA            Algeria           Algiers    Africa
# 3     213  ASM     American Samoa         Pago Pago   Oceania
# 4     203  AND            Andorra  Andorra la Vella    Europe
# ..    ...  ...                ...               ...       ...
# 229   226  WLF  Wallis and Futuna          Mata-Utu   Oceania
# 230   172  ESH     Western Sahara          El Aaiún    Africa
# 231    46  YEM              Yemen             Sanaa      Asia
# 232    63  ZMB             Zambia            Lusaka    Africa
# 233    74  ZWE           Zimbabwe            Harare    Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0           41128771         38972230         33753499         28189672
# 1            2842321          2866849          2882481          2913399
# ...

# %% [markdown]
# ### Percentaje
# In this part we are gonna check the percentaje of the CSV and find how many percentaje that we don't have

# %%
#Checking world percentaje
print('Total percentaje % ' + str(population['World Population Percentage'].sum()) )
print('Missing: % ' + str(100-population['World Population Percentage'].sum()))
# Out:
# Total percentaje % 99.93
# Missing: % 0.06999999999999318

# %% [markdown]
# ### Countries
# How many countries do we have per each continent?

# %%
#We obtania a panda series
table=population['Continent'].value_counts()

#we convert the series into a data frame
df_continents=pd.DataFrame({'Continent':table.index,'nCountries':table.values})
display(df_continents)


#We have a dataFrame with 6 continents and how many countries it has every continent
# Out:
#        Continent  nCountries
# 0         Africa          57
# 1           Asia          50
# 2         Europe          50
# 3  North America          40
# 4        Oceania          23
# 5  South America          14

# %% [markdown]
# # Comparative density/growth rate

# %%
#DataFrame with values of density per each continent
#first, define df
df_result = pd.DataFrame(columns=['Continent','Density','Growth Rate'])

#exctract every continent in a list
names=df_continents['Continent'].values.tolist()

#a function for filter a density of every country in a continent
def sum_density(parameter):
    #filter for continent
    filter_continent=population[population['Continent']==parameter]
    
    #sumatory of every value
    density=filter_continent.loc[:,['Density (per km²)']].sum()
    grow=filter_continent.loc[:,['Growth Rate']].sum()
    
    #df of density
    df_density=pd.DataFrame({'Continent':parameter,'Density':density.values,'Growth Rate':grow.values})
    return df_density

#in this loop df of density it's append in the final df
#for continent in names:
    #df_result = df_result.append(sum_density(continent), ignore_index=True)
    #df_result = pd.concat([df_result, sum_density(continent)], ignore_index=True)

df_result = pd.concat(df_continents['Continent'].apply(sum_density).tolist(), ignore_index=True)
    
#print(df_result.to_string(index=True))
print('Continents by Growth Rate')
display(df_result.sort_values(by='Growth Rate', ascending=False))

print('Continents by Density')
display(df_result.sort_values(by='Density', ascending=False))

#sumatory of square kilometers in the earth
print('Earth: '+ str(population.loc[:,['Area (km²)']].sum()))
# Out:
# Continents by Growth Rate
#        Continent     Density  Growth Rate
# 0         Africa   7127.7158      58.2109
# 1           Asia  51251.2068      50.4692
# 2         Europe  33166.2371      50.1128
# 3  North America  10910.4703      40.1670
# 4        Oceania   3048.4905      23.1698
# 5  South America    293.6077      14.1114
# Continents by Density
#        Continent     Density  Growth Rate
# 1           Asia  51251.2068      50.4692
# 2         Europe  33166.2371      50.1128
# 3  North America  10910.4703      40.1670
# 0         Africa   7127.7158      58.2109
# 4        Oceania   3048.4905      23.1698
# 5  South America    293.6077      14.1114
# Earth: Area (km²)    136059156
# dtype: int64

# %% [markdown]
# ## Graphs
# Africa it's the continent with the highest growth rate in the world but it isn't the continent with the highest density. On the other hand Asia and Europe has similar datas of growth rate and they are the continents with the highest density in the world. The next test it's similar but checking countries.

# %%
#Graphs
plt.style.use('dark_background')

cont= df_result['Continent']
den= df_result['Density']
gro=df_result['Growth Rate']

fig, axes =plt.subplots(1,2,figsize=(10,5))

axes[0].bar(cont,den,width=0.4,color=['yellow','#00FFFF'])
axes[1].bar(cont,gro,width=0.4,color=['yellow','#00FFFF'])

axes[0].tick_params(axis='x', rotation=45)
axes[1].tick_params(axis='x', rotation=45)

axes[0].set_xlabel('Continents')
axes[0].set_ylabel('per km²')

axes[1].set_xlabel('Continents')
axes[1].set_ylabel('Growth Rate')

axes[0].set_title('Density by Continent')
axes[1].set_title('Growth Rate by Continent')

plt.show()

# %% [markdown]
# ## Graphs by each continent
# ### Comparsion between Density and Growt rate

# %%
def charter(table):
    #Function for make graphs, with 3 variables

    c= table['Country/Territory']
    
    #random numbers for diferent colors in each bubble
    d= np.random.randint(10, 220, size=10)
    e= table['Density (per km²)']
    f= table['Growth Rate']
    sns.scatterplot(data=a,x=f,y=e)
        #using seaborn, saved more lines of code.
        
        
#     #its defined an object where the graph will be printed
#     fig, axes =plt.subplots()
#     axes.set_title('Comparative density/growth rate') #Tittle
#     #Scatter graph in the variable "s"
#     s=axes.scatter(c,f,e,d)   
    
#     #customize
#     axes.set_xlabel('Continents')
#     axes.tick_params(axis='x', rotation=45)
    
#     axes.set_ylabel('Growth Rate')
#     axes.set_ylim(0.925, 1.075)
    
#     #customize for the legend
#     #legend_elements with diferents size
#     handles, labels = s.legend_elements(prop="sizes", alpha=0.2,color='#00FFFF')
#     #position
#     legend2 = axes.legend(handles, labels, loc="upper right", title="Density (per km²)",bbox_to_anchor=(1.40,1))
    

    plt.show()

def checking(parameter):
    filter_continent=population[population['Continent']==parameter]
    by_country=filter_continent.loc[:,['Country/Territory','Density (per km²)','Growth Rate']]
    
    
    df_result2= pd.DataFrame(by_country).sort_values(by='Density (per km²)', ascending=False)
    #df_result2_tail = pd.DataFrame(by_country).sort_values(by='Density (per km²)', ascending=False).tail(3)

    #df_result2 = pd.concat([df_result2_head,df_result2_tail])
    print(parameter)
    display(df_result2.head(5))
    charter(df_result2)
    

    
df_continents['Continent'].apply(checking)
# Out:
# Africa
#     Country/Territory  Density (per km²)  Growth Rate
# 130           Mayotte           871.9278       1.0319
# 129         Mauritius           636.9946       1.0004
# 172            Rwanda           523.0731       1.0234
# 32            Burundi           463.0874       1.0270
# 43            Comoros           449.3953       1.0184
# Asia
#     Country/Territory  Density (per km²)  Growth Rate
# 119             Macau         23172.2667       1.0125
# 187         Singapore          8416.4634       1.0058
# 89          Hong Kong          6783.3922       0.9992
# 15            Bahrain          1924.4876       1.0061
# 123          Maldives          1745.9567       1.0045
# Europe
#     Country/Territory  Density (per km²)  Growth Rate
# 134            Monaco         18234.5000       0.9941
# 76          Gibraltar          5441.5000       0.9994
# 125             Malta          1687.6139       1.0124
# 103            Jersey           954.9828       1.0106
# ...

# %% [markdown]
# # Area and Percentage
#
# We do a df with separations between countries per continent

# %%
population.groupby(['Continent','Country/Territory']).agg({'Area (km²)':'sum','World Population Percentage':'sum'})
# Out:
#                                  Area (km²)  World Population Percentage
# Continent     Country/Territory
# Africa        Algeria               2381741                         0.56
#               Angola                1246700                         0.45
#               Benin                  112622                         0.17
#               Botswana               582000                         0.03
#               Burkina Faso           272967                         0.28
# ...                                     ...                          ...
# South America Paraguay               406752                         0.09
#               Peru                  1285216                         0.43
#               Suriname               163820                         0.01
#               Uruguay                181034                         0.04
#               Venezuela              916445                         0.35
#
# [234 rows x 2 columns]

# %% [markdown]
# ### Filter only for African countries

# %%
#Filter by continent
cont=population['Continent'] == 'Africa'
population[cont].head(10)

# we order the data by World Population Percentage
a=population[cont].groupby(['Country/Territory']).agg({'Area (km²)':'sum','World Population Percentage':'sum'}).sort_values(by='World Population Percentage',ascending=False)
a
# Out:
#                           Area (km²)  World Population Percentage
# Country/Territory
# Nigeria                       923768                         2.74
# Ethiopia                     1104300                         1.55
# Egypt                        1002450                         1.39
# DR Congo                     2344858                         1.24
# Tanzania                      945087                         0.82
# South Africa                 1221037                         0.75
# Kenya                         580367                         0.68
# Uganda                        241550                         0.59
# Sudan                        1886068                         0.59
# Algeria                      2381741                         0.56
# Morocco                       446550                         0.47
# Angola                       1246700                         0.45
# Ghana                         238533                         0.42
# ...

# %% [markdown]
# ### Correlation matrix

# %%
a.corr()
# Out:
#                              Area (km²)  World Population Percentage
# Area (km²)                     1.000000                     0.480185
# World Population Percentage    0.480185                     1.000000

# %% [markdown]
# ### Heatmap of top 5 countries

# %%
sns.heatmap(a.head(10),annot=True)
plt.show()

# %% [markdown]
# ### Ploting of the compairson of Percentaje/Area

# %%
x = a['Area (km²)']
y = a['World Population Percentage']
sns.scatterplot(x=x,y=y)
sns.regplot(x=x,y=y)
plt.show()
